# %% [markdown]
# ### Clone repository

# %%
# !git clone https://github.com/7embl4/speech-synthesis.git
# %cd speech-synthesis
# Out:
# Cloning into 'speech-synthesis'...
# remote: Enumerating objects: 418, done.
# remote: Counting objects: 100% (418/418), done.
# remote: Compressing objects: 100% (227/227), done.
# remote: Total 418 (delta 228), reused 333 (delta 168), pack-reused 0 (from 0)
# Receiving objects: 100% (418/418), 105.60 KiB | 1.65 MiB/s, done.
# Resolving deltas: 100% (228/228), done.
# /content/speech-synthesis

# %% [markdown]
# ### Install requirements

# %%
# !pip install torch==2.6.0 torchaudio==2.6.0 torchvision==0.21.0 --index-url https://download.pytorch.org/whl/cu126
# !pip install -r requirements.txt

# %% [markdown]
# ## Download models

# %%
# !mkdir models

# pretrained hifigan
# !huggingface-cli download artem1085715/hifigan hifigan.pth --local-dir models

# neural MOS model
# !wget -P models https://github.com/gabrielmittag/NISQA/raw/refs/heads/master/weights/nisqa_mos_only.tar
# Out:
# ⚠️  Warning: 'huggingface-cli download' is deprecated. Use 'hf download' instead.
# ...
# hifigan.pth: 100% 418M/418M [00:03<00:00, 111MB/s]
# Download complete. Moving file to models/hifigan.pth
# models/hifigan.pth
# --2026-01-24 13:23:08--  https://github.com/gabrielmittag/NISQA/raw/refs/heads/master/weights/nisqa_mos_only.tar
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/gabrielmittag/NISQA/refs/heads/master/weights/nisqa_mos_only.tar [following]
# --2026-01-24 13:23:08--  https://raw.githubusercontent.com/gabrielmittag/NISQA/refs/heads/master/weights/nisqa_mos_only.tar
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# ...

# %% [markdown]
# ### Create .env file

# %%
# %%writefile .env
# CUSTOM_DATASET_URL=https://disk.360.yandex.ru/d/Mzh9T9OEZKSsww
# Out:
# Writing .env

# %% [markdown]
# ### Run synthesis

# %% [markdown]
# #### Usual

# %%
# !python synthesize.py \
    --text_dir data/datasets/custom_dataset \
    --results_dir results
# Out:
# 2026-01-24 13:26:15.828999: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769261175.845594    1952 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769261175.850548    1952 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1769261175.863550    1952 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !ls results
# Out:
# generated_0.wav  generated_2.wav  generated_4.wav
# generated_1.wav  generated_3.wav  gen_from_cli_2026.01.24_13.24.05.wav

# %%
import IPython.display as ipd

audio_path = "results/generated_1.wav"
ipd.Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# #### From cli

# %%
# !python synthesize.py \
    --text "text" \
    --results_dir results

# %%
# !ls results
# Out:
# gen_from_cli_2026.01.24_13.24.05.wav

# %%
ipd.Audio("results/gen_from_cli_2026.01.24_13.24.05.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
